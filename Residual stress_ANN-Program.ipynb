# %%
import pandas as pd
import numpy as np

# %%
np.set_printoptions(suppress=True)
 
residualstress=pd.read_csv('Final used data.csv')
residualstress.head()
# Out:
#    Depo_Temp  Bias Voltage (-V)  Thickness  (nm)  Residual Stress  (GPa)  \
# 0        300                 19           1500.0                   -2.62
# 1        300                 20           1500.0                   -2.63
# 2        300                 22           1500.0                   -2.62
# 3        300                 24           1500.0                   -2.67
# 4        300                 26           1500.0                   -2.69
#
#   Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0        NaN         NaN         NaN    0.126667        0.75   -0.261477
# 1        NaN         NaN         NaN    0.133333        0.75   -0.262475
# 2        NaN         NaN         NaN    0.146667        0.75   -0.261477
# 3        NaN         NaN         NaN    0.160000        0.75   -0.266467
# 4        NaN         NaN         NaN    0.173333        0.75   -0.268463

# %%
print(residualstress.columns)
# Out:
# Index(['Depo_Temp', 'Bias Voltage (-V)', 'Thickness  (nm)',
#        'Residual Stress  (GPa)', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Assuming you've loaded the dataset into the 'residualstress' DataFrame

TargetVariable = ['Residual Stress  (GPa)']
Predictors = ['Depo_Temp', 'Bias Voltage (-V)', 'Thickness  (nm)']

X = residualstress[Predictors].values
y = residualstress[TargetVariable].values

# Standardization of data
PredictorScaler = StandardScaler()
TargetVarScaler = StandardScaler()

# Storing the fit object for later reference
PredictorScalerFit = PredictorScaler.fit(X)
TargetVarScalerFit = TargetVarScaler.fit(y)

# Generating the standardized values of X and y
X = PredictorScalerFit.transform(X)
y = TargetVarScalerFit.transform(y)

# Split the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Quick sanity check with the shapes of Training and testing datasets
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (500, 3)
# y_train shape: (500, 1)
# X_test shape: (215, 3)
# y_test shape: (215, 1)

# %%
# Original data
X = residualstress[Predictors].values
y = residualstress[TargetVariable].values

# Split the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardization of data
PredictorScaler = StandardScaler()

# Fit the scaler on training predictors and transform both training and testing predictors
X_train = PredictorScaler.fit_transform(X_train)
X_test = PredictorScaler.transform(X_test)

# %%
import keras
from keras.models import Sequential

# %%
from keras.layers import Dense, Dropout, Activation
from keras.layers import Input, Dense, Flatten
from keras.optimizers import SGD


model = Sequential()

# %%
model.add(Dense(units=7, input_dim=3, kernel_initializer='normal', activation='tanh'))

# %%
model.add(Dense(units=7, kernel_initializer='normal', activation='tanh'))

# %%
model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))

# %%
model.add(Dense(1, kernel_initializer='normal'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train ,batch_size = 20, epochs = 1000, verbose=1)
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 1s 2ms/step - loss: 19.8374
# Epoch 2/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 19.4385
# Epoch 3/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 18.6393
# Epoch 4/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 17.0829
# Epoch 5/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 14.9219
# Epoch 6/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 12.7614
# Epoch 7/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 10.9947
# Epoch 8/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 9.6233
# Epoch 9/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 8.6216
# Epoch 10/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 7.8589
# Epoch 11/1000
# 25/25 [==============================] - 0s 2ms/step - loss: 7.2567
# Epoch 12/1000
# ...

# %%
history = model.fit(
    X_train,  # Training data
    y_train,  # Training labels
    epochs=1000,  # Number of training epochs
    batch_size=20,  # Batch size
    validation_data=(X_test, y_test)  # Validation data and labels
)
# Out:
# Epoch 1/1000
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0355 - val_loss: 0.0669
# Epoch 2/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0338 - val_loss: 0.0620
# Epoch 3/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0328 - val_loss: 0.0605
# Epoch 4/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0322 - val_loss: 0.0606
# Epoch 5/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0327 - val_loss: 0.0614
# Epoch 6/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0331 - val_loss: 0.0640
# Epoch 7/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0343 - val_loss: 0.0626
# Epoch 8/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0361 - val_loss: 0.0674
# Epoch 9/1000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0354 - val_loss: 0.0609
# Epoch 10/1000
# ...

# %%
# Import necessary libraries
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# Your data preparation code
X = residualstress[Predictors].values
y = residualstress[TargetVariable].values

# Split the data into training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardization of data
PredictorScaler = StandardScaler()

# Fit the scaler on training predictors and transform both training and testing predictors
X_train = PredictorScaler.fit_transform(X_train)
X_test = PredictorScaler.transform(X_test)

# Build and train the neural network
model = Sequential()
model.add(Dense(units=7, input_dim=3, kernel_initializer='normal', activation='tanh'))
model.add(Dense(units=7, kernel_initializer='normal', activation='relu'))
model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
model.add(Dense(units=3, kernel_initializer='normal', activation='relu'))

model.add(Dense(units=3, kernel_initializer='normal', activation='tanh'))
model.add(Dense(1, kernel_initializer='normal'))
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(
    X_train,  # Training data
    y_train,  # Training labels
    epochs=1000,  # Number of training epochs
    batch_size=20,  # Batch size
    validation_data=(X_test, y_test)  # Validation data and labels
)

# Compile the model with the 'mean_squared_error' metric
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# Train the model and store the history
history = model.fit(
    X_train,  # Training data
    y_train,  # Training labels
    epochs=1000,  # Number of training epochs
    batch_size=20,  # Batch size
    validation_data=(X_test, y_test)  # Validation data and labels
)

# Extract training and testing MSE from the history object
training_mse = history.history['mean_squared_error']
testing_mse = history.history['val_mean_squared_error']

# Get the last MSE values (at the end of training)
final_training_mse = training_mse[-1]
final_testing_mse = testing_mse[-1]

print(f"Final Training MSE: {final_training_mse}")
print(f"Final Testing MSE: {final_testing_mse}")
# Out:
# Epoch 1/500
# 25/25 [==============================] - 1s 12ms/step - loss: 19.8530 - val_loss: 19.9494
# Epoch 2/500
# 25/25 [==============================] - 0s 4ms/step - loss: 19.5626 - val_loss: 19.6160
# Epoch 3/500
# 25/25 [==============================] - 0s 4ms/step - loss: 19.1659 - val_loss: 19.1207
# Epoch 4/500
# 25/25 [==============================] - 0s 4ms/step - loss: 18.5293 - val_loss: 18.2630
# Epoch 5/500
# 25/25 [==============================] - 0s 4ms/step - loss: 17.4072 - val_loss: 16.7724
# Epoch 6/500
# 25/25 [==============================] - 0s 4ms/step - loss: 15.6407 - val_loss: 14.8494
# Epoch 7/500
# 25/25 [==============================] - 0s 4ms/step - loss: 13.8002 - val_loss: 13.1959
# Epoch 8/500
# 25/25 [==============================] - 0s 4ms/step - loss: 12.3818 - val_loss: 11.9941
# Epoch 9/500
# 25/25 [==============================] - 0s 4ms/step - loss: 11.3543 - val_loss: 11.0898
# Epoch 10/500
# ...

# %%
# Predict stress values on the training data
y_train_pred = model.predict(X_train)
# Out:
# 16/16 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predict stress values on the training data
y_train_pred = model.predict(X_train)

# Flatten the arrays to make them 1D
y_train = y_train.flatten()
y_train_pred = y_train_pred.flatten()

# Create a scatter plot of actual vs. predicted stress values with bubbles
plt.scatter(y_train, y_train_pred, s=50, label='Actual vs. Predicted', facecolors='none', edgecolors='grey')

# Calculate the regression line (best-fit line)
regression_line = np.polyfit(y_train, y_train_pred, 1)
x_values = np.linspace(min(y_train), max(y_train), 100)
y_values = np.polyval(regression_line, x_values)

# Plot the regression line
plt.plot(x_values, y_values, 'black', label='Regression Line', linewidth=2)

plt.xlabel('Actual Residual Stress')
plt.ylabel('Predicted Residual Stress')
plt.title('Training Data: Actual vs. Predicted Stress')
plt.legend(loc='best')

plt.savefig("Training Data Regression line.pdf",dpi=300)
plt.show()
# Out:
# 16/16 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predict stress values on the testing data
y_test_pred = model.predict(X_test)

# Flatten the arrays to make them 1D
y_test = y_test.flatten()
y_test_pred = y_test_pred.flatten()

# Create a scatter plot of actual vs. predicted stress values with bubbles
plt.scatter(y_test, y_test_pred, s=50, label='Actual vs. Predicted', c='red', alpha=0.5)

# Calculate the regression line (best-fit line)
regression_line = np.polyfit(y_test, y_test_pred, 1)
x_values = np.linspace(min(y_test), max(y_test), 100)
y_values = np.polyval(regression_line, x_values)

# Plot the regression line
plt.plot(x_values, y_values, 'b-', label='Regression Line', linewidth=2)

plt.xlabel('Actual Residual Stress')
plt.ylabel('Predicted Residual Stress')
plt.title('Testing Data: Actual vs. Predicted Residual Stress')
plt.legend(loc='best')
plt.savefig("Testing Data Regression line.pdf",dpi=300)
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score

# Predict stress values on the training data
y_train_pred = model.predict(X_train)
# Predict stress values on the testing data
y_test_pred = model.predict(X_test)

# Calculate R-squared values for training and testing data
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f"R-squared (R2) for Training Data: {r2_train:.4f}")
print(f"R-squared (R2) for Testing Data: {r2_test:.4f}")
# Out:
# ...
# 7/7 [==============================] - 0s 2ms/step
# R-squared (R2) for Training Data: 0.9936
# R-squared (R2) for Testing Data: 0.9875

# %%
from sklearn.metrics import r2_score

# Predict stress values on the training and testing data
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Combine the actual and predicted values for both training and testing datasets
y_actual = np.concatenate((y_train, y_test))
y_predicted = np.concatenate((y_train_pred, y_test_pred))

# Calculate the overall R-squared value
overall_r2 = r2_score(y_actual, y_predicted)

print(f"Overall R-squared (R2) for the Model: {overall_r2:.4f}")
# Out:
# ...
# 7/7 [==============================] - 0s 4ms/step
# Overall R-squared (R2) for the Model: 0.9918

# %%
from sklearn.metrics import mean_squared_error

# Predict stress values on the training and testing data
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Combine the actual and predicted values for both training and testing datasets
y_actual = np.concatenate((y_train, y_test))
y_predicted = np.concatenate((y_train_pred, y_test_pred))

# Calculate the overall MSE
overall_mse = mean_squared_error(y_actual, y_predicted)

print(f"Overall Mean Squared Error (MSE) for the Model: {overall_mse:.4f}")
# Out:
# ...
# 7/7 [==============================] - 0s 3ms/step
# Overall Mean Squared Error (MSE) for the Model: 0.0396

# %%
import matplotlib.pyplot as plt

# Predict stress values on the training and testing data
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Combine the actual and predicted values for both training and testing datasets
y_actual = np.concatenate((y_train, y_test))
y_predicted = np.concatenate((y_train_pred, y_test_pred))

# Calculate the absolute percentage error (APE) for each data point
ape = np.abs((y_actual - y_predicted) / y_actual) * 100

# Create a scatter plot of APE values over datapoints
plt.scatter(y_actual, ape, s=50, c='b', alpha=0.5)
plt.xlabel('Actual Stress')
plt.ylabel('Absolute Percentage Error (%)')
plt.title('Absolute Percentage Error Over Data Points')
plt.show()

# %%
# Use the trained model to make predictions on unseen data
predictions = model.predict(X_unseen)

# 'predictions' now contains the model's predictions for the unseen data

# Optionally, you can evaluate the model's performance on this unseen data
from sklearn.metrics import mean_squared_error

# Assuming you have the true labels for the unseen data as 'y_unseen'
mse = mean_squared_error(y_unseen, predictions)
print(f"Mean Squared Error (MSE) on Unseen Data: {mse}")

# %%
X_train
# Out:
# array([[ 0.68644971, -0.3913657 ,  0.71743221],
#        [ 0.68644971,  0.08231522,  0.71743221],
#        [ 0.68644971,  0.04722774,  0.71743221],
#        ...,
#        [ 0.68644971,  1.02967706, -0.38223579],
#        [-1.48204047, -0.35627823, -0.54126133],
#        [ 0.68644971,  1.02967706, -1.03737344]])

# %%
y_train
# Out:
# array([[ -3.13 ],
#        [ -3.41 ],
#        [ -3.39 ],
#        [ -3.96 ],
#        [ -4.795],
#        [ -1.17 ],
#        [ -2.16 ],
#        [ -3.83 ],
#        [ -2.81 ],
#        [ -2.6  ],
#        [ -1.19 ],
#        [ -4.639],
#        [ -3.067],
#        [ -1.65 ],
#        [ -8.16 ],
#        [ -2.787],
#        [ -1.36 ],
#        [ -4.624],
#        [ -5.78 ],
#        [ -2.27 ],
#        [ -6.072],
#        [ -3.97 ],
#        [ -1.83 ],
#        [ -8.28 ],
#        [ -1.11 ],
#        [ -5.62 ],
#        [ -6.01 ],
#        [ -3.03 ],
#        [ -2.89 ],
#        [ -4.32 ],
#        [ -6.69 ],
#        [ -5.58 ],
#        [ -2.958],
#        [ -7.72 ],
#        [ -2.631],
#        [ -8.99 ],
#        [ -3.347],
#        [ -5.247],
#        [ -1.7  ],
#        [ -2.678],
#        [ -3.22 ],
#        [ -2.709],
#        [ -2.569],
#        [ -2.77 ],
#        [ -3.503],
#        [ -3.02 ],
#        [ -3.939],
#        [ -7.05 ],
#        [ -1.47 ],
#        [ -2.569],
# ...

# %%
X_test
# Out:
# array([[ 0.68644971,  1.02967706, -1.02555832],
#        [ 0.68644971, -0.51417187,  2.76866892],
#        [ 0.68644971, -0.05803468,  0.71743221],
#        [ 0.68644971,  1.02967706, -0.09894633],
#        [-0.98234491, -1.60188361,  1.40117778],
#        [-1.48204047, -0.37382196, -0.52638303],
#        [ 0.68644971,  0.76652099,  0.71743221],
#        [-1.48204047, -1.07557148, -0.04540905],
#        [ 0.68644971,  1.17002696,  0.71743221],
#        [ 0.66759327, -1.60188361,  0.03368664],
#        [ 0.68644971,  1.02967706,  0.65946426],
#        [ 0.68644971,  1.02967706, -1.04326733],
#        [-1.48204047, -0.40890944, -0.49659907],
#        [ 0.68644971,  1.02967706, -1.05212867],
#        [ 0.68644971,  1.02967706, -0.83669412],
#        [-1.48204047, -0.54925934, -0.40727455],
#        [ 0.68644971,  1.02967706, -0.67144649],
#        [ 0.68644971,  1.02967706, -0.44421049],
#        [ 0.3187492 ,  0.15249017,  1.40117778],
#        [-1.48204047, -0.1106659 , -0.70503207],
# ...

# %%
y_test
# Out:
# array([[-5.434],
#        [-0.89 ],
#        [-3.33 ],
#        [-2.911],
#        [-1.03 ],
#        [-7.68 ],
#        [-3.81 ],
#        [-4.95 ],
#        [-4.06 ],
#        [-1.71 ],
#        [-2.6  ],
#        [-5.947],
#        [-7.49 ],
#        [-6.087],
#        [-4.141],
#        [-6.93 ],
#        [-3.658],
#        [-3.254],
#        [-2.62 ],
#        [-8.79 ],
#        [-3.61 ],
#        [-4.126],
#        [-0.64 ],
#        [-1.31 ],
#        [-4.546],
#        [-5.293],
#        [-3.845],
#        [-3.94 ],
#        [-6.119],
#        [-1.39 ],
#        [-4.2  ],
#        [-5.574],
#        [-2.6  ],
#        [-6.45 ],
#        [-6.041],
#        [-1.23 ],
#        [-4.04 ],
#        [-4.47 ],
#        [-5.231],
#        [-2.678],
#        [-5.325],
#        [-1.36 ],
#        [-1.54 ],
#        [-3.425],
#        [-4.11 ],
#        [-3.52 ],
#        [-2.631],
#        [-2.569],
#        [-4.079],
#        [-7.45 ],
#        [-5.729],
#        [-4.92 ],
# ...

# %%
def make_regression_ann(Optimizer_trial):
    from keras.models import Sequential
    from keras.layers import Dense
    
    model = Sequential()
    model.add(Dense(units=5, input_dim=3, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(units=3, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(units=3, kernel_initializer='normal', activation='tanh'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer=Optimizer_trial)
    return model
 
###########################################
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor
 
# Listing all the parameters to try
Parameter_Trials={'batch_size':[20,30],
                      'epochs':[100,500],
                    'Optimizer_trial':['adam', 'rmsprop']
                 }
 
# Creating the regression ANN model
RegModel=KerasRegressor(make_regression_ann, verbose=0)
 
###########################################
from sklearn.metrics import make_scorer
 
# Defining a custom function to calculate accuracy
def Accuracy_Score(orig,pred):
    MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
    print('#'*70,'Accuracy:', 100-MAPE)
    return(100-MAPE)
 
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)
 
#########################################
# Creating the Grid search space
# See different scoring methods by using sklearn.metrics.SCORERS.keys()
grid_search=GridSearchCV(estimator=RegModel, 
                         param_grid=Parameter_Trials, 
                         scoring=custom_Scoring, 
                         cv=5)
 
#########################################
# Measuring how much time it took to find the best params
import time
StartTime=time.time()
 
# Running Grid Search for different paramenters
grid_search.fit(X,y, verbose=1)
 
EndTime=time.time()
print("########## Total Time Taken: ", round((EndTime-StartTime)/60), 'Minutes')
 
print('### Printing Best parameters ###')
grid_search.best_params_
# Out:
# Epoch 1/100
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7116\4140354755.py:24: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   RegModel=KerasRegressor(make_regression_ann, verbose=0)
# 29/29 [==============================] - 0s 2ms/step - loss: 19.7688
# Epoch 2/100
# 29/29 [==============================] - 0s 2ms/step - loss: 19.3415
# Epoch 3/100
# 29/29 [==============================] - 0s 2ms/step - loss: 18.6004
# Epoch 4/100
# 29/29 [==============================] - 0s 2ms/step - loss: 17.4993
# Epoch 5/100
# 29/29 [==============================] - 0s 2ms/step - loss: 16.2332
# Epoch 6/100
# 29/29 [==============================] - 0s 2ms/step - loss: 15.0180
# Epoch 7/100
# 29/29 [==============================] - 0s 2ms/step - loss: 13.9155
# Epoch 8/100
# ...

# %%
def function_find_best_params(X_train, y_train, X_test, y_test):
    batch_size_list = [20, 30]
    epoch_list = [ 100,200]
    
    search_results_data = []
    
    trial_number = 0
    for batch_size_trial in batch_size_list:
        for epochs_trial in epoch_list:
            trial_number += 1
            
            model = Sequential()
            model.add(Dense(units=7, input_dim=X_train.shape[1], kernel_initializer='normal', activation='tanh'))
            model.add(Dense(units=7, kernel_initializer='normal', activation='relu'))
            model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
            model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
            model.add(Dense(units=3, kernel_initializer='normal', activation='tanh'))
            model.add(Dense(1, kernel_initializer='normal'))
            model.compile(loss='mean_squared_error', optimizer='adam')
            model.fit(X_train, y_train, batch_size=batch_size_trial, epochs=epochs_trial, verbose=0)
            
            MAPE = np.mean(100 * (np.abs(y_test - model.predict(X_test)) / y_test))
            
            print(f'Trial {trial_number}: Parameters - batch_size: {batch_size_trial}, epochs: {epochs_trial}, MAPE: {MAPE}')
            
            search_results_data.append({
                'TrialNumber': trial_number,
                'Parameters': f"{batch_size_trial}-{epochs_trial}",
                'MAPE_Score': 100 - MAPE
            })
            
    return pd.DataFrame(search_results_data)

# Example usage
# results = function_find_best_params(X_train, y_train, X_test, y_test)
# print(results)

# %%
resultsdata=function_find_best_params(X_train, y_train, X_test, y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step
# Trial 1: Parameters - batch_size: 20, epochs: 100, MAPE: -28.757770904990092
# 7/7 [==============================] - 0s 2ms/step
# Trial 2: Parameters - batch_size: 20, epochs: 200, MAPE: -20.120590062923416
# 7/7 [==============================] - 0s 2ms/step
# Trial 3: Parameters - batch_size: 30, epochs: 100, MAPE: -34.42353772245032
# 7/7 [==============================] - 0s 2ms/step
# Trial 4: Parameters - batch_size: 30, epochs: 200, MAPE: -15.823513485271107

# %%
import matplotlib.pyplot as plt
resultsdata.plot(x='Parameters', y='MAPE_Score', figsize=(15,4), kind='line')
# Out:
# <Axes: xlabel='Parameters'>

# %%
model.fit(X_train, y_train ,batch_size = 30, epochs = 200, verbose=0)
 
# Generating Predictions on testing data
Predictions=model.predict(X_test)
 
# Scaling the predicted Price data back to original price scale
Predictions=TargetVarScalerFit.inverse_transform(Predictions)
 
# Scaling the y_test Price data back to original price scale
y_test_orig=TargetVarScalerFit.inverse_transform(y_test)
 
# Scaling the test data back to original scale
Test_Data=PredictorScalerFit.inverse_transform(X_test)
 
TestingData=pd.DataFrame(data=Test_Data, columns=Predictors)
TestingData['residualstress']=y_test_orig
TestingData['Predictedresidualstress']=Predictions
TestingData.head()
# Out:
# 7/7 [==============================] - 0s 2ms/step
#     Depo_Temp  Bias Voltage (-V)  Thickness  (nm)  residualstress  \
# 0  301.411828         151.883398       227.223667      -15.818850
# 1  301.411828          63.380434      3021.804700       -5.855003
# 2  301.411828          89.529037      1510.997139      -11.205308
# 3  301.411828         151.883398       909.705802      -10.286547
# 4  127.537388           1.026073      2014.599660       -6.161988
#
#    Predictedresidualstress
# 0               -15.842059
# 1                -5.833621
# 2               -11.366040
# 3               -10.151879
# 4                -5.921106

# %%
APE=100*(abs(TestingData['residualstress']-TestingData['Predictedresidualstress'])/TestingData['residualstress'])
TestingData['APE']=APE
 
print('The Accuracy of ANN model is:', 100-np.mean(APE))
TestingData.head()
# Out:
# The Accuracy of ANN model is: 104.86012440473405
#     Depo_Temp  Bias Voltage (-V)  Thickness  (nm)  residualstress  \
# 0  301.411828         151.883398       227.223667      -15.818850
# 1  301.411828          63.380434      3021.804700       -5.855003
# 2  301.411828          89.529037      1510.997139      -11.205308
# 3  301.411828         151.883398       909.705802      -10.286547
# 4  127.537388           1.026073      2014.599660       -6.161988
#
#    Predictedresidualstress       APE
# 0               -15.842059 -0.146721
# 1                -5.833621 -0.365191
# 2               -11.366040 -1.434430
# 3               -10.151879 -1.309159
# 4                -5.921106 -3.909150

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(TestingData['APE'], bins=20, edgecolor='black')
plt.xlabel('Absolute Percentage Error (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Absolute Percentage Errors')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(TestingData['residualstress'], TestingData['Predictedresidualstress'], color='blue')
plt.plot([min(TestingData['residualstress']), max(TestingData['residualstress'])], 
         [min(TestingData['residualstress']), max(TestingData['residualstress'])], 
         color='red', linestyle='--', linewidth=2)
plt.xlabel('Actual Residual Stress')
plt.ylabel('Predicted Residual Stress')
plt.title('Actual vs. Predicted Residual Stress')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(TestingData.index, TestingData['APE'], marker='o', linestyle='-', color='green')
plt.xlabel('Data Points')
plt.ylabel('Absolute Percentage Error (%)')
plt.title('Absolute Percentage Error Over Data Points')
plt.show()

# %%
from sklearn.metrics import explained_variance_score

# Assuming you have true target values (y_true) and predicted target values (y_pred)
explained_var_score = explained_variance_score(TestingData['residualstress'],TestingData['Predictedresidualstress'])

print("Explained Variance Score:", explained_var_score)
# Out:
# Explained Variance Score: 0.969709823208484

# %%
from sklearn.metrics import r2_score

# Assuming you have true target values (y_true), predicted target values (y_pred), and the number of predictors (n_predictors)
r2 = r2_score(TestingData['residualstress'], TestingData['Predictedresidualstress'])
n = len(TestingData['residualstress'])
adj_r2 = 1 - ((1 - r2) * (215 - 1) / (215 - 3 - 1))

print("Adjusted R²:", adj_r2)
# Out:
# Adjusted R²: 0.9690400793540106

# %%
from sklearn.metrics import mean_squared_error

# Assuming you have true target values (y_true) and predicted target values (y_pred)
mse = mean_squared_error(TestingData['residualstress'], TestingData['Predictedresidualstress'])
rmse = np.sqrt(mse)

print("Root Mean Square Error:", rmse)
# Out:
# Root Mean Square Error: 0.8469392550513708

# %%
residualstress
# Out:
#      Depo_Temp  Bias Voltage (-V)  Thickness  (nm)  Residual Stress  (GPa)  \
# 0          300                 19           1500.0                   -2.62
# 1          300                 20           1500.0                   -2.63
# 2          300                 22           1500.0                   -2.62
# 3          300                 24           1500.0                   -2.67
# 4          300                 26           1500.0                   -2.69
# ..         ...                ...              ...                     ...
# 710        238                100           2000.0                   -2.56
# 711        261                100           2000.0                   -2.62
# 712        283                100           2000.0                   -2.70
# 713        306                100           2000.0                   -2.77
# 714        329                100           2000.0                   -2.82
#
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_train,  color='blue')
plt.plot(model.predict(X_train), model.predict(X_train), color='red',linestyle='--',  linewidth=2)
plt.show()
# Out:
# ...
# 16/16 [==============================] - 0s 2ms/step
